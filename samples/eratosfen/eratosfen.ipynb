// %% [raw]
// compile some of 'eratosfen.cpp' files
// alternative way to run the eratosfen sample from the Terminal:
// 1) cd ~/samples/eratosfen
// 2) g++ eratosfen.cpp -I ~/lib -o eratosfen
// 3) ./eratosfen

// %%
!g++ eratosfen.cpp -I ~/lib -o eratosfen

// %% [raw]
// run eratosfen sample

// %%
!./eratosfen
